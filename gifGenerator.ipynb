# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
import os
import imageio

# %%
rootDir = '/content/drive/My Drive/flagsDataset/generated/'

filenames = os.listdir('/content/drive/My Drive/flagsDataset/generated/')

images = []
for filename in filenames:
  print(filename)
  path = os.path.join(rootDir,filename) 
  images.append(imageio.imread(path))
imageio.mimsave('/content/drive/My Drive/flagsDataset/movie.gif', images)
# Out:
# image1.png
# image11.png
# image21.png
# image31.png
# image41.png
# image51.png
# image61.png
# image71.png
# image81.png
# image91.png
# image101.png
# image111.png
# image121.png
# image131.png
# image141.png
# image151.png
# image161.png
# image171.png
# image181.png
# image191.png
# image201.png
# image211.png
# image221.png
# image231.png
# image241.png
# image251.png
# image261.png
# image271.png
# image281.png
# image291.png
# image301.png
# image311.png
# image321.png
# image331.png
# image341.png
# image351.png
# image361.png
# image371.png
# image381.png
# image391.png
# image401.png
# image411.png
# image421.png
# image431.png
# image441.png
# image451.png
# image461.png
# image471.png
# image481.png
# image491.png
# image501.png
# image511.png
# image521.png
# image531.png
# image541.png
# image551.png
# image561.png
# image571.png
# image581.png
# image591.png
# image601.png
# image611.png
# image621.png
# image631.png
# image641.png
# image651.png
# image661.png
# ...
